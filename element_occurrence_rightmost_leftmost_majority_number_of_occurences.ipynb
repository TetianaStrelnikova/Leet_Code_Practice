# %% [markdown]
# ### Challenge 1
#
# This variation of a common binary search problem is frequently asked during phone interviews.
#
# ---
#
# ### 🧠 Problem Statement
#
# You are given an array of integers `nums`, sorted in **non-decreasing order**, and a number `target`.
#
# **Return `True`** only if `target` is a **majority element**.
#
# If the `target` is not found in the array, return `False`.
#
# ---
#
# ### 🔢 Definition
#
# A **majority element** is an element that appears **more than** `n / 2` times in an array of length `n`.
#
# ---
#
# ### 🔒 Constraints
#
# - `1 ≤ nums.length ≤ 10^3`
# - `-10^3 ≤ nums[i] ≤ 10^3`
# - `1 ≤ target ≤ 10^3`
#
# ---
#
# ### 💡 Examples
#
# **Example 1**
# Input: `nums = [2,4,5,5,5,5,5,6,6]`, `target = 5`
# Output: `True`
# Explanation: `5` appears 5 times, and `5 > 9 / 2` → True
#
# ---
#
# **Example 2**
# Input: `nums = [10,100,101,101]`, `target = 101`
# Output: `False`
# Explanation: `101` appears 2 times, and `2 > 4 / 2` → False
#
# ---
#
# **Example 3**
# Input: `nums = [-10]`, `target = 10`
# Output: `False`
# Explanation: `10` is not found in the array.

# %%
# we need an binary search 
# which will find the leftmost 
# and the rightmost occurence of the element
# lftmost will be boolean
def binary_search_occurrences(arr, target, leftmost):
    low = 0
    high = len(arr) - 1
    
    while low + 1 <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            if leftmost:
                high = mid
            else:
                low = mid 
        elif arr[mid] < target:
            low = mid
        else:
            high = mid
    if arr[low] == target:
        
        #TODO: finish!!!!!!!!!!!!!!!!
